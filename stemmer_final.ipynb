# %%
import pandas as pd
import re

# %%
df1 = pd.read_csv('dictionary_cleaned2.txt')
df2 = pd.read_csv('test.txt')

# %%
df1.shape
# Out:
# (439091, 1)

# %%
df2.shape
# Out:
# (4136, 1)

# %%
train = df1['content'].values.tolist()
test = df2['content'].values.tolist()

# %%
#1
p1= r".*ে$"
p2= r".*র$"
p3= r".*য়$"
p36 = r".*ই$"
p37 = r".*ও$"

#2
p4 = r".*কে$"
p5 = r".*রে$"
p6= r".*রা$"
p7= r".*গণ$"
p8= r".*তে$"
p9= r".*ের$"
p10= r".*এর$"
p39 = r".*টি$"
p40 = r".*েই$"
p41 = r".*সহ$"
p44 = r".*েও$"

#3
p11= r".*েরা$"
p12= r".*বন্দ$"
p13= r".*েরে$"
p14= r".*দের$"
p15= r".*দিগ$"
p16= r".*েতে$"
p34 = r".*য়ের$"
p42 = r".*টির$"
p48 = r".*টাই$"

#4
p17= r".*গুলি$"
p18= r".*গুলো$"
p19= r".*সমূহ$"
p20= r".*দিয়া$"
p21= r".*দিয়ে$"
p22= r".*দিগে$"
p38 = r".*ভাবে$"
p43 = r".*টিতে$"
p46 = r".*টিকে$"


#5
p23= r".*দিগকে$"
p24= r".*দেরকে$"
p25= r".*গুলির$"
p26= r".*গুলোর$"
p27= r".*দিগের$"
p28= r".*বৃন্দ$"
p35= r".*গুলোর$"


#6
p29= r".*দিগেরে$"
p30= r".*দিগেতে$"
p31= r".*গুলিতে$"
p45= r".*গুলোকে$"
p47= r".*গুলোতে$"
#p= r".*$"

#7
p32= r".*বৃন্দের$"
p33= r".*দিগেরকে$"


t1 = r"\.*াচ্ছেন$"
t2 = r"\.*াচ্ছে$"
t3 = r"\.*াচ্ছ$"
t4 = r"\.*াচ্ছিলাম$"
t5 = r"\.*াচ্ছিলা$"
t6 = r"\.*াচ্ছিলেন$"
t7 = r"\.*াচ্ছিলে$"
t8 = r"\.*াচ্ছিল$"
t9 = r"\.*াচ্ছিস$"
t10 = r"\.*াচ্ছি$"

t11 = r"\.*িচ্ছেন$"
t12 = r"\.*িচ্ছে$"
t13 = r"\.*িচ্ছ$"
t14 = r"\.*িচ্ছিলাম$"
t15 = r"\.*িচ্ছিলা$"
t16 = r"\.*িচ্ছিলেন$"
t17 = r"\.*িচ্ছিলে$"
t18 = r"\.*িচ্ছিল$"
t19 = r"\.*িচ্ছিস$"
t20 = r"\.*িচ্ছি$"

t21 = r"\.*েয়েছে$"
t22 = r"\.*িয়েছে$"
t23 = r"\.*য়েছে$"
t24 = r"\.*ছে$"
t25 = r"\.*েছে$"

t26 = r"\.*েয়েছ$"
t27 = r"\.*িয়েছ$"
t28 = r"\.*য়েছ$"


r1 = "ায়"
r2 = "েয়"
r3 = "িয়"
r4 = "য়"
r5 = "ছ"
r6 = "েছ"

# %%
from bangla_stemmer.stemmer import stemmer
stmr = stemmer.BanglaStemmer()
with open('Output_update1.1.txt', 'w', encoding="utf-8") as fob:
    
    for check in test:
            stemmer = check
            check2 = check

            for pp in range(1,10):
                temp = 1
                if re.match(p1, check) or re.match(p2, check) or re.match(p3, check) or re.match(p36, check) or re.match(p37, check):
                    ck = check[:-1]
                    if ck in train:
                        temp=0
                        stemmer = ck

                if (re.match(p41,check) or re.match(p40,check) or re.match(p39,check) or re.match(p4,check) or re.match(p5,check) or re.match(p6,check) or re.match(p7,check) or re.match(p8,check) or re.match(p9,check) or re.match(p10,check)):

                        ck = check[:-2]
                        if ck in train:
                            temp = 0
                            stemmer = ck

                if (re.match(p42,check) or re.match(p34,check) or re.match(p11,check) or re.match(p12,check) or re.match(p13,check) or re.match(p14,check) or re.match(p15,check) or re.match(p16,check)):
                    ck = check[:-3]
                    if ck in train:
                        temp= 0
                        stemmer = ck

                if (re.match(p38,check) or re.match(p17,check) or re.match(p18,check) or re.match(p19,check) or re.match(p20,check) or re.match(p21,check) or re.match(p22,check)):
                    ck = check[:-4]
                    if ck in train:
                        temp= 0
                        stemmer = ck

                if (re.match(p35,check) or re.match(p23,check) or re.match(p24,check) or re.match(p25,check) or re.match(p26,check) or re.match(p27,check) or re.match(p28,check)):
                    ck = check[:-5]
                    if ck in train:
                        temp= 0
                        stemmer = ck

                if (re.match(p29,check) or re.match(p30,check) or re.match(p31,check)):
                    ck = check[:-6]
                    if ck in train:
                        temp= 0
                        stemmer = ck

                if (re.match(p32,check) or re.match(p33,check)):
                    ck = check[:-7]
                    if ck in train:
                        temp= 0
                        stemmer = ck

                if temp==0:
                    check = stemmer


                if temp==1:
                    pr = check
                    pr1= re.sub(t1,r1,pr)
                    pr2 = re.sub(t2, r1,pr1)
                    pr3 = re.sub(t3, r1,pr2)
                    pr4 = re.sub(t4, r1,pr3)
                    pr5 = re.sub(t5, r1,pr4)
                    pr6 = re.sub(t6, r1,pr5)
                    pr7 = re.sub(t7, r1,pr6)
                    pr8 = re.sub(t8, r1,pr7)
                    pr9 = re.sub(t9, r1,pr8)
                    pr10 = re.sub(t10, r1,pr9)

                    pr11 = re.sub(t11, r2,pr10)
                    pr12 = re.sub(t12, r2,pr11)
                    pr13 = re.sub(t13, r2,pr12)
                    pr14 = re.sub(t14, r2,pr13)
                    pr15 = re.sub(t15, r2,pr14)
                    pr16 = re.sub(t16, r2,pr15)
                    pr17 = re.sub(t17, r2,pr16)
                    pr18 = re.sub(t18, r2,pr17)
                    pr19 = re.sub(t19, r2,pr18)
                    pr20 = re.sub(t20, r2,pr19)

                    pr21 = re.sub(t21, r1,pr20)
                    pr22 = re.sub(t22, r3,pr21)
                    pr23 = re.sub(t23, r4,pr22)
                    pr24 = re.sub(t24, r5,pr23)
                    pr25 = re.sub(t25, r6,pr24)

                    pr26 = re.sub(t26, r1,pr25)
                    pr27 = re.sub(t27, r3,pr26)
                    pr28 = re.sub(t28, r4,pr27)

                    pr29 = re.sub(r"\.*েয়েছেন$", "ায়",pr28)
                    pr30 = re.sub(r"\.*িয়েছেন$"," িয়",pr29)
                    pr31 = re.sub(r"\.*য়েছেন$","য়",pr30)
                    pr32 = re.sub(r"\.*েছেন$","েছ",pr31)
                    pr33 = re.sub(r"\.*ছেন$","ছ",pr32)

                    pr34 = re.sub(r"\.*েয়েছিল$","ায়",pr33)
                    pr35 = re.sub(r"\.*িয়েছিল$","িয়",pr34)
                    pr36 = re.sub(r"\.*য়েছিল$","য়",pr35)
                    pr37 = re.sub(r"\.*েছিল$","েছ",pr36)
                    pr38 = re.sub(r"\.*ছিল$","ছ",pr37)

                    pr39 = re.sub(r"\.*েয়েছিলা$","ায়",pr38)
                    pr40 = re.sub(r"\.*িয়েছিলা$","িয়",pr39)
                    pr41 = re.sub(r"\.*য়েছিলা$","য়",pr40)
                    pr42 = re.sub(r"\.*েছিলা$","েছ",pr41)
                    pr43 = re.sub(r"\.*ছিলা$","ছ",pr42)

                    pr44 = re.sub(r"\.*েয়েছিলাম$","ায়",pr43)
                    pr45 = re.sub(r"\.*িয়েছিলাম$","িয়",pr44)
                    pr46 = re.sub(r"\.*য়েছিলাম$","য়",pr45)
                    pr47 = re.sub(r"\.*েছিলাম$","েছে",pr46)
                    pr48 = re.sub(r"\.*ছিলাম$","ছ",pr47)

                    pr49 = re.sub(r"\.*েয়েছিলেন$","ায়",pr48)
                    pr50 = re.sub(r"\.*িয়েছিলেন$","িয়",pr49)
                    pr51 = re.sub(r"\.*য়েছিলেন$","য়",pr50)
                    pr52 = re.sub(r"\.*েছিলেন$","েছ",pr51)
                    pr53 = re.sub(r"\.*ছিলেন$","ছ",pr52)

                    pr54 = re.sub(r"\.*েয়েছিলে$","ায়",pr53)
                    pr55 = re.sub(r"\.*িয়ছিলে$","িয়",pr54)
                    pr56 = re.sub(r"\.*য়েছিলে$","য়",pr55)
                    pr57 = re.sub(r"\.*েছিলে$","েছ",pr56)
                    pr58 = re.sub(r"\.*ছিলে$","ছ",pr57)

                    pr59 = re.sub(r"\.*েয়েছিলি$","ায়",pr58)
                    pr60 = re.sub(r"\.*িয়েছিলি$","িয়",pr59)
                    pr61 = re.sub(r"\.*য়েছিলি$","য়",pr60)
                    pr62 = re.sub(r"\.*েছিলি$","েছ",pr61)
                    pr63 = re.sub(r"\.*ছিলি$","ছ",pr62)

                    pr64 = re.sub(r"\.*েয়েছিস$","ায়",pr63)
                    pr65 = re.sub(r"\.*িয়েছিস$","িয়",pr64)
                    pr66 = re.sub(r"\.*য়েছিস$","য়",pr65)
                    pr67 = re.sub(r"\.*ইছিস$","য়",pr66)
                    pr68 = re.sub(r"\.*ছিস$","ছ",pr67)

                    pr69 = re.sub(r"\.*েয়ে$","ায়",pr68)
                    pr70 = re.sub(r"\.*ইয়ে$","য়",pr69)
                    pr71 = re.sub(r"\.*ায়ে$","া",pr70)
                    pr72 = re.sub(r"\.*য়ে$","য়",pr71)
                    print(pp)
                    stm = stmr.stem(check2)
                    fob.write('{} --> {} --> {}\n'.format(check2,stm,pr72))
                    break
# Out:
# 1
# applied fourth rules..
# 1
# applied fourth rules..
# 2
# applied first rules..
# 1
# applied fourth rules..
# 2
# applied first rules..
# 1
# 1
# applied first rules..
# 2
# applied third rules..
# 2
# 1
# 1
# 1
# 1
# 1
# 2
# applied fourth rules..
# 2
# applied second rules..
# 1
# applied fourth rules..
# 1
# applied first rules..
# 1
# 1
# applied fourth rules..
# 1
# applied first rules..
# 2
# applied second rules..
# 1
# applied first rules..
# 2
# 1
# applied first rules..
# 2
# applied first rules..
# applied fourth rules..
# 2
# 1
# applied first rules..
# 1
# applied second rules..
# 1
# applied fourth rules..
# 1
# applied second rules..
# 3
# applied first rules..
# applied fourth rules..
# 1
# 1
# applied fourth rules..
# 1
# 1
# applied fourth rules..
# 1
# 2
# applied second rules..
# 1
# 1
# 2
# applied fourth rules..
# 1
# 2
# applied fourth rules..
# 2
# 1
# applied first rules..
# 1
# 2
# applied first rules..
# 1
# 2
# applied second rules..
# 1
# 2
# ...
